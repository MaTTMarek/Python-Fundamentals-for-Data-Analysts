# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 3.In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
df_orders_products_combined = pd.read_pickle(r'C:\Users\mateu\Desktop\Master_Folder\02 Data\Prepared Data\orders_products_combined.pkl')

# %% [markdown]
# ## 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
# check
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  order_dow  \
# 0           0             0   2539329        1             1          2
# 1           0             0   2539329        1             1          2
# 2           0             0   2539329        1             1          2
# 3           0             0   2539329        1             1          2
# 4           0             0   2539329        1             1          2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True       196.0
# 1                  8                     NaN         True     14084.0
# 2                  8                     NaN         True     12427.0
# 3                  8                     NaN         True     26088.0
# 4                  8                     NaN         True     26405.0
#
#    add_to_cart_order  reordered _merge
# 0                1.0        0.0   both
# ...

# %%
#converting decimals into numbers in df_orders_products_combined
df_orders_products_combined['product_id'] = pd.to_numeric(['df_orders_products_combined'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "df_orders_products_combined"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1192/4670942.py in <module>
#       1 #converting decimals into numbers in df_orders_products_combined
# ----> 2 df_orders_products_combined['product_id'] = pd.to_numeric(['df_orders_products_combined'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
# ...

# %%
#converting decimals into numbers in df_orders_products_combined
df_orders_products_combined[['product_id']] = df_orders_products_combined [['product_id',]].apply(pd.to_numeric)

# %%
# check
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  order_dow  \
# 0           0             0   2539329        1             1          2
# 1           0             0   2539329        1             1          2
# 2           0             0   2539329        1             1          2
# 3           0             0   2539329        1             1          2
# 4           0             0   2539329        1             1          2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True       196.0
# 1                  8                     NaN         True     14084.0
# 2                  8                     NaN         True     12427.0
# 3                  8                     NaN         True     26088.0
# 4                  8                     NaN         True     26405.0
#
#    add_to_cart_order  reordered _merge
# 0                1.0        0.0   both
# ...

# %%
df_orders_products_combined.shape
# Out:
# (32640698, 13)

# %%
# changing data type
df_orders_products_combined['product_id'] = df_orders_products_combined['product_id'].fillna(0).astype(int)

# %%
# import data set
df_prod = pd.read_csv(r'C:\Users\mateu\Desktop\Master_Folder\02 Data\Prepared Data\products_clean.csv')

# %%
df_prod.head(20)# checking file content
# Out:
#     Unnamed: 0  product_id                                       product_name  \
# 0            0           1                         Chocolate Sandwich Cookies
# 1            1           2                                   All-Seasons Salt
# 2            2           3               Robust Golden Unsweetened Oolong Tea
# 3            3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4            4           5                          Green Chile Anytime Sauce
# 5            5           6                                       Dry Nose Oil
# 6            6           7                     Pure Coconut Water With Orange
# 7            7           8                  Cut Russet Potatoes Steam N' Mash
# 8            8           9                  Light Strawberry Blueberry Yogurt
# 9            9          10     Sparkling Orange Juice & Prickly Pear Beverage
# 10          10          11                                  Peach Mango Juice
# ...

# %%
# drop column
df_prod=df_prod.drop (columns = ['Unnamed: 0']) #Unnamed column is useless

# %%
df_prod.head()#checking the resoult
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prod.shape
# Out:
# (49672, 5)

# %% [markdown]
# 5.Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# drop few others columns
df_orders_products_combined_new =df_orders_products_combined.drop(columns = ['_merge','Unnamed: 0','Unnamed: 0.1'])

# %%
df_orders_products_combined_new #checking the resoult
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32640693   2977660   206209            13          1                 12
# 32640694   2977660   206209            13          1                 12
# 32640695   2977660   206209            13          1                 12
# 32640696   2977660   206209            13          1                 12
# 32640697    272231   206209            14          6                 14
#
#           days_since_prior_order  first_order  product_id  add_to_cart_order  \
# ...

# %%
# merging
df_orders_prods_merged = df_orders_products_combined_new.merge(df_prod, on = ['product_id'], how = 'left',indicator = True)

# %%
df_orders_prods_merged #checking the result
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32641263   2977660   206209            13          1                 12
# 32641264   2977660   206209            13          1                 12
# 32641265   2977660   206209            13          1                 12
# 32641266   2977660   206209            13          1                 12
# 32641267    272231   206209            14          6                 14
#
#           days_since_prior_order  first_order  product_id  add_to_cart_order  \
# ...

# %% [markdown]
# #  6.Confirm the results of the merge using the merge flag

# %%
df_orders_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only       236409
# right_only           0
# Name: _merge, dtype: int64

# %%
# saving
df_orders_prods_merged.to_pickle (r'C:\Users\mateu\Desktop\Master_Folder\02 Data\Prepared Data\orders_prods_merged.pkl')
