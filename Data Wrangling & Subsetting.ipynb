# %%
#Imported libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\mateu\Desktop\CF\Master Folder'

# %%
# importing file
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
# deleting column
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# renaame columns
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
# check
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# changing data type in order_id
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# check
df_ords ['order_id'].dtype
# Out:
# dtype('O')

# %%
# adding new file
df_prods= pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
# adding another new file
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
# check
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# take first row of df.drp.t for a header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# data under the header as new data
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# set the header row as a new header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {0: 'frozen'},
#  '2': {0: 'other'},
#  '3': {0: 'bakery'},
#  '4': {0: 'produce'},
#  '5': {0: 'alcohol'},
#  '6': {0: 'international'},
#  '7': {0: 'beverages'},
#  '8': {0: 'pets'},
#  '9': {0: 'dry goods pasta'},
#  '10': {0: 'bulk'},
#  '11': {0: 'personal care'},
#  '12': {0: 'meat seafood'},
#  '13': {0: 'pantry'},
#  '14': {0: 'breakfast'},
#  '15': {0: 'canned goods'},
#  '16': {0: 'dairy eggs'},
#  '17': {0: 'household'},
#  '18': {0: 'babies'},
#  '19': {0: 'snacks'},
#  '20': {0: 'deli'},
#  '21': {0: 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
# Subseting
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
# Question 2-14

# %%
# Question 2 
# Find another identifier variable in the df_ords dataframe that doesn’t need to be 
# included in your analysis as a numeric variable and change it to
# a suitable format.

# %%
df_ords.head()#closer look to ds_ords
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Question 3
# Look for a variable in your df_ords dataframe with 
# an unintuitive name and change its name without overwriting the data frame.

# %%
df_newords=df_ords.rename(columns = {'order_hour_of_day' : 'hour_of_order'}, inplace = False) 
# don't use inplace=True

# %%
df_newords.head()
# Out:
#   order_id user_id  order_number  order_dow  hour_of_order  \
# 0  2539329       1             1          2              8
# 1  2398795       1             2          3              7
# 2   473747       1             3          3             12
# 3  2254736       1             4          4              7
# 4   431534       1             5          4             15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Question 4
# Your client wants to know what the busiest hour is for placing orders. 
# Find the frequency of the corresponding variable and share your findings.

# %%
df_newords['hour_of_order'].value_counts(dropna = False).max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: hour_of_order, dtype: int64>

# %%
# The busiest time of the day is 10 and max value is 288418

# %%
# Question 5
# Determine the meaning behind a value of 4 in the "department_id" column within 
# the df_prods dataframe using a data dictionary.

# %%
df_prods.head() #data dictionary already has been created
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# Question 6
# The sales team in your client’s organization wants to know more about breakfast item sales. 
# Create a subset containing only the required information.

# %%
data_dict #breakefast is 14
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_bf= df_prods[df_prods['department_id']==14]

# %%
df_bf.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
# Question 7
# They’d also like to see details about customers who might be throwing dinner parties. 
# Your task is to find all observations from the entire dataframe that include items 
# from the following departments: alcohol, deli, beverages, and meat/seafood. 
# You’ll need to present this subset to your client.

# %%
df_newlist=df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_newlist.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %%
df_newlist.shape
# Out:
# (7650, 5)

# %%
#Number of rows is 7650 and column is 5 in df_newlist

# %%
# Question 9
# Someone from the data engineers team in Instacart thinks they’ve spotted something strange 
# about the customer with a "user_id" of “1.” 
# Extract all the information you can about this user.

# %%
df_user_id_1=df_newords[df_newords['user_id']=='1']

# %%
df_user_id_1.head(100)
# Out:
#    order_id user_id  order_number  order_dow  hour_of_order  \
# 0   2539329       1             1          2              8
# 1   2398795       1             2          3              7
# 2    473747       1             3          3             12
# 3   2254736       1             4          4              7
# 4    431534       1             5          4             15
# 5   3367565       1             6          2              7
# 6    550135       1             7          1              9
# 7   3108588       1             8          1             14
# 8   2295261       1             9          1             16
# 9   2550362       1            10          4              8
# 10  1187899       1            11          4              8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# 6                     20.0
# ...

# %%
# Question 10 
# You also need to provide some details about this user’s behavior. 
# What basic stats can you provide based on the information you have?

# %%
df_user_id_1.describe()
# Out:
#        order_number  order_dow  hour_of_order  days_since_prior_order
# count     11.000000  11.000000      11.000000               10.000000
# mean       6.000000   2.636364      10.090909               19.000000
# std        3.316625   1.286291       3.477198                9.030811
# min        1.000000   1.000000       7.000000                0.000000
# 25%        3.500000   1.500000       7.500000               14.250000
# 50%        6.000000   3.000000       8.000000               19.500000
# 75%        8.500000   4.000000      13.000000               26.250000
# max       11.000000   4.000000      16.000000               30.000000

# %%
# Question 12
# Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder
# so that you have a “.csv” file of your departments data in the correct format.

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))
