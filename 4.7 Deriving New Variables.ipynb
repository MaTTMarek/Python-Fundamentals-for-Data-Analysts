# %%
# imprt libraries
import pandas as pd
import numpy as np
import os

# %%
# import data set
ords_prods_merge = pd.read_pickle(r'C:\Users\mateu\Desktop\Master_Folder\02 Data\Prepared Data\orders_prods_merged.pkl')

# %%
# Subset of df
df = ords_prods_merge[:1000000]

# %%
#checking the result
df.shape
# Out:
# (1000000, 15)

# %%
#checking the result
df.shape
# Out:
# (1000000, 15)

# %%
# creating price range with if 
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\mateu\AppData\Local\Temp/ipykernel_3216/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts (dropna = False)
# Out:
# Mid-range product    668114
# Low-range product    312168
# High range            12340
# Not enough data        7378
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
# loc function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\mateu\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\mateu\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     668114
# Low-range product     312168
# High-range product     12340
# NaN                     7378
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### back to entire dataframe

# %%
# price range distribution wit loc finction
ords_prods_merge.loc[(ords_prods_merge ['prices'] <= 15) & (ords_prods_merge ['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# check
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    21860860
# NaN                  10780408
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merge['order_dow'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: order_dow, dtype: int64

# %%
# If 
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22575937
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7
#
# Question 2

# %%
# creating new variable
ords_result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    ords_result.append("Busiest_days")
  elif value == 1:
    ords_result.append("Busiest_days")
  elif value == 3:
    ords_result.append("Slowest_days")
  elif value ==4:
    ords_result.append("Slowest_days")
  else:
    ords_result.append("Regularly busy")

# %%
# check
ords_result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
# adding new column
ords_prods_merge['Busiest_day'] = ords_result

# %%
# check
ords_prods_merge['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    13010466
# Busiest_days      11949665
# Slowest_days       7681137
# Name: Busiest_day, dtype: int64

# %% [markdown]
# There are more Busiest_days and Slowest_days and less Regularly Busy

# %% [markdown]
# # Question 4

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2781009
# 11    2755369
# 14    2709084
# 15    2682090
# 13    2680171
# 12    2637533
# 16    2554110
# 9     2471067
# 17    2104225
# 8     1729871
# 18    1649870
# 19    1268365
# 20     983232
# 7      897163
# 21     801052
# 22     638671
# 23     405051
# 6      292533
# 0      220337
# 1      116589
# 5       88661
# 2       69904
# 4       53636
# 3       51675
# Name: order_hour_of_day, dtype: int64

# %%
# 10 am is on the top, than 11,14...

# %%
# gruping variables
time_result = []

for value in ords_prods_merge["order_hour_of_day"]:
  if value > 10 & value <=18:
    time_result.append("Most_orders")
  elif value <=5:
    time_result.append("Fewest_orders")
  else:
    time_result.append("Average_orders")

# %%
# check
time_result
# Out:
# ['Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
# ...

# %% [markdown]
# Create new column name titled 'busiest_period_of_day.'

# %%
ords_prods_merge['Busiest_period_of_day'] = time_result

# %% [markdown]
# # Question 5

# %%
ords_prods_merge['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       27840147
# Average_orders     4510880
# Fewest_orders       290241
# Name: Busiest_period_of_day, dtype: int64

# %%
# check
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                1.0
# 1                     NaN         True       14084                2.0
# 2                     NaN         True       12427                3.0
# 3                     NaN         True       26088                4.0
# 4                     NaN         True       26405                5.0
#
#    reordered                             product_name  aisle_id  \
# 0        0.0                                     Soda      77.0
# ...

# %% [markdown]
# # Question 7
# Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
# saving
ords_prods_merge.to_pickle (r'C:\Users\mateu\Desktop\Master_Folder\02 Data\Prepared Data\orders_prods_merged.pkl')
